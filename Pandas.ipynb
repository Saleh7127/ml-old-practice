# %%
import pandas as pd

# %%
print(pd.__version__)
# Out:
# 2.2.2

# %%
df = pd.read_csv('flights.csv')

# %%
pd.set_option('display.max_columns',100)

# %%
df.head(5)
# Out:
#    Unnamed: 0  FlightDate                                    Airline Origin  \
# 0           0  2022-04-04  Commutair Aka Champlain Enterprises, Inc.    GJT
# 1           1  2022-04-04  Commutair Aka Champlain Enterprises, Inc.    HRL
# 2           2  2022-04-04  Commutair Aka Champlain Enterprises, Inc.    DRO
# 3           3  2022-04-04  Commutair Aka Champlain Enterprises, Inc.    IAH
# 4           4  2022-04-04  Commutair Aka Champlain Enterprises, Inc.    DRO
#
#   Dest  Cancelled  Diverted  CRSDepTime  DepTime  DepDelayMinutes  DepDelay  \
# 0  DEN      False     False        1133   1123.0              0.0     -10.0
# 1  IAH      False     False         732    728.0              0.0      -4.0
# 2  DEN      False     False        1529   1514.0              0.0     -15.0
# 3  GPT      False     False        1435   1430.0              0.0      -5.0
# 4  DEN      False     False        1135   1135.0              0.0       0.0
#
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4078318, step=1)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'FlightDate', 'Airline', 'Origin', 'Dest', 'Cancelled',
#        'Diverted', 'CRSDepTime', 'DepTime', 'DepDelayMinutes', 'DepDelay',
#        'ArrTime', 'ArrDelayMinutes', 'AirTime', 'CRSElapsedTime',
#        'ActualElapsedTime', 'Distance', 'Year', 'Quarter', 'Month',
#        'DayofMonth', 'DayOfWeek', 'Marketing_Airline_Network',
#        'Operated_or_Branded_Code_Share_Partners', 'DOT_ID_Marketing_Airline',
#        'IATA_Code_Marketing_Airline', 'Flight_Number_Marketing_Airline',
#        'Operating_Airline', 'DOT_ID_Operating_Airline',
#        'IATA_Code_Operating_Airline', 'Tail_Number',
#        'Flight_Number_Operating_Airline', 'OriginAirportID',
#        'OriginAirportSeqID', 'OriginCityMarketID', 'OriginCityName',
#        'OriginState', 'OriginStateFips', 'OriginStateName', 'OriginWac',
#        'DestAirportID', 'DestAirportSeqID', 'DestCityMarketID', 'DestCityName',
#        'DestState', 'DestStateFips', 'DestStateName', 'DestWac', 'DepDel15',
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0              int64
# FlightDate             object
# Airline                object
# Origin                 object
# Dest                   object
#                        ...
# ArrDel15              float64
# ArrivalDelayGroups    float64
# ArrTimeBlk             object
# DistanceGroup           int64
# DivAirportLandings      int64
# Length: 62, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4078318 entries, 0 to 4078317
# Data columns (total 62 columns):
#  #   Column                                   Dtype
# ---  ------                                   -----
#  0   Unnamed: 0                               int64
#  1   FlightDate                               object
#  2   Airline                                  object
#  3   Origin                                   object
#  4   Dest                                     object
#  5   Cancelled                                bool
#  6   Diverted                                 bool
#  7   CRSDepTime                               int64
#  8   DepTime                                  float64
#  9   DepDelayMinutes                          float64
#  10  DepDelay                                 float64
#  11  ArrTime                                  float64
#  12  ArrDelayMinutes                          float64
#  13  AirTime                                  float64
# ...

# %%
df.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4078318 entries, 0 to 4078317
# Columns: 62 entries, Unnamed: 0 to DivAirportLandings
# dtypes: bool(2), float64(18), int64(24), object(18)
# memory usage: 1.8+ GB

# %%
df.describe()
# Out:
#          Unnamed: 0    CRSDepTime       DepTime  DepDelayMinutes  \
# count  4.078318e+06  4.078318e+06  3.957885e+06     3.957823e+06
# mean   2.920989e+05  1.329587e+03  1.334374e+03     1.601494e+01
# std    1.695040e+05  4.904801e+02  5.056219e+02     5.231498e+01
# min    0.000000e+00  1.000000e+00  1.000000e+00     0.000000e+00
# 25%    1.456540e+05  9.140000e+02  9.170000e+02     0.000000e+00
# 50%    2.913080e+05  1.320000e+03  1.325000e+03     0.000000e+00
# 75%    4.369620e+05  1.735000e+03  1.744000e+03     1.100000e+01
# max    6.187890e+05  2.359000e+03  2.400000e+03     7.223000e+03
#
#            DepDelay       ArrTime  ArrDelayMinutes       AirTime  \
# count  3.957823e+06  3.954079e+06     3.944916e+06  3.944916e+06
# mean   1.309049e+01  1.457886e+03     1.578307e+01  1.110075e+02
# std    5.332016e+01  5.431841e+02     5.198424e+01  6.996246e+01
# min   -7.800000e+01  1.000000e+00     0.000000e+00  8.000000e+00
# ...

# %%
df['Airline'].describe()
# Out:
# count                    4078318
# unique                        21
# top       Southwest Airlines Co.
# freq                      731925
# Name: Airline, dtype: object

# %%
df.shape, len(df)
# Out:
# ((4078318, 62), 4078318)

# %%
df[['OriginWac',	'DestAirportID','DestAirportSeqID','DestCityMarketID']]
# Out:
#          OriginWac  DestAirportID  DestAirportSeqID  DestCityMarketID
# 0               82          11292           1129202             30325
# 1               74          12266           1226603             31453
# 2               82          11292           1129202             30325
# 3               74          11973           1197302             31973
# 4               82          11292           1129202             30325
# ...            ...            ...               ...               ...
# 4078313         72          11618           1161802             31703
# 4078314         36          11618           1161802             31703
# 4078315         22          13930           1393007             30977
# 4078316         21          14122           1412202             30198
# 4078317         21          14492           1449202             34492
#
# [4078318 rows x 4 columns]

# %%
df.columns[61:]
# Out:
# Index(['DivAirportLandings'], dtype='object')

# %%
[c for c in df.columns if 'Time' in c]
# Out:
# ['CRSDepTime',
#  'DepTime',
#  'ArrTime',
#  'AirTime',
#  'CRSElapsedTime',
#  'ActualElapsedTime',
#  'DepTimeBlk',
#  'CRSArrTime',
#  'ArrTimeBlk']

# %%
df[[c for c in df.columns if 'Time' in c]]
# Out:
#          CRSDepTime  DepTime  ArrTime  AirTime  CRSElapsedTime  \
# 0              1133   1123.0   1228.0     40.0            72.0
# 1               732    728.0    848.0     55.0            77.0
# 2              1529   1514.0   1636.0     47.0            70.0
# 3              1435   1430.0   1547.0     57.0            90.0
# 4              1135   1135.0   1251.0     49.0            70.0
# ...             ...      ...      ...      ...             ...
# 4078313        1949   2014.0    234.0      NaN           185.0
# 4078314        1733   1817.0      NaN      NaN           129.0
# 4078315        1700   2318.0     59.0    135.0           158.0
# 4078316        2129   2322.0    939.0      NaN            86.0
# 4078317        1154   1148.0   1556.0      NaN            99.0
#
#          ActualElapsedTime DepTimeBlk  CRSArrTime ArrTimeBlk
# 0                     65.0  1100-1159        1245  1200-1259
# 1                     80.0  0700-0759         849  0800-0859
# ...

# %%
df.select_dtypes('int')
# Out:
#          Unnamed: 0  CRSDepTime  Year  Quarter  Month  DayofMonth  DayOfWeek  \
# 0                 0        1133  2022        2      4           4          1
# 1                 1         732  2022        2      4           4          1
# 2                 2        1529  2022        2      4           4          1
# 3                 3        1435  2022        2      4           4          1
# 4                 4        1135  2022        2      4           4          1
# ...             ...         ...   ...      ...    ...         ...        ...
# 4078313      590537        1949  2022        1      3          31          4
# 4078314      590538        1733  2022        1      3          17          4
# 4078315      590539        1700  2022        1      3           8          2
# 4078316      590540        2129  2022        1      3          25          5
# 4078317      590541        1154  2022        1      3           7          1
#
# ...

# %%
type(df['Airline']), type(df[['Airline']])
# Out:
# (pandas.core.series.Series, pandas.core.frame.DataFrame)

# %%
df.iloc[:3,:3]
# Out:
#    Unnamed: 0  FlightDate                                    Airline
# 0           0  2022-04-04  Commutair Aka Champlain Enterprises, Inc.
# 1           1  2022-04-04  Commutair Aka Champlain Enterprises, Inc.
# 2           2  2022-04-04  Commutair Aka Champlain Enterprises, Inc.

# %%
df['Airline'] != 'Commutair Aka Champlain Enterprises, Inc.'
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 4078313     True
# 4078314     True
# 4078315     True
# 4078316     True
# 4078317     True
# Name: Airline, Length: 4078318, dtype: bool

# %%
df.loc[(df['Airline'] == 'Commutair Aka Champlain Enterprises, Inc.') & (df['FlightDate']=='2022-04-04')]
# Out:
#         Unnamed: 0  FlightDate                                    Airline  \
# 0                0  2022-04-04  Commutair Aka Champlain Enterprises, Inc.
# 1                1  2022-04-04  Commutair Aka Champlain Enterprises, Inc.
# 2                2  2022-04-04  Commutair Aka Champlain Enterprises, Inc.
# 3                3  2022-04-04  Commutair Aka Champlain Enterprises, Inc.
# 4                4  2022-04-04  Commutair Aka Champlain Enterprises, Inc.
# ...            ...         ...                                        ...
# 580285      580285  2022-04-04  Commutair Aka Champlain Enterprises, Inc.
# 580286      580286  2022-04-04  Commutair Aka Champlain Enterprises, Inc.
# 580287      580287  2022-04-04  Commutair Aka Champlain Enterprises, Inc.
# 580288      580288  2022-04-04  Commutair Aka Champlain Enterprises, Inc.
# 580289      580289  2022-04-04  Commutair Aka Champlain Enterprises, Inc.
#
#        Origin Dest  Cancelled  Diverted  CRSDepTime  DepTime  DepDelayMinutes  \
# ...

# %%
df.query('DepTime>2323')
# Out:
#          Unnamed: 0  FlightDate                 Airline Origin Dest  \
# 1939           1939  2022-04-01  Southwest Airlines Co.    ATL  TPA
# 2100           2100  2022-04-01  Southwest Airlines Co.    BNA  ECP
# 2151           2151  2022-04-01  Southwest Airlines Co.    BNA  PHX
# 2297           2297  2022-04-01  Southwest Airlines Co.    BWI  BUF
# 2308           2308  2022-04-01  Southwest Airlines Co.    BWI  CMH
# ...             ...         ...                     ...    ...  ...
# 4076073      588297  2022-03-24       Republic Airlines    EWR  MEM
# 4076192      588416  2022-03-24       Republic Airlines    IAD  CMH
# 4076874      589098  2022-03-27       Republic Airlines    EWR  MHT
# 4078041      590265  2022-03-31       Republic Airlines    BNA  EWR
# 4078079      590303  2022-03-31       Republic Airlines    IND  EWR
#
#          Cancelled  Diverted  CRSDepTime  DepTime  DepDelayMinutes  DepDelay  \
# ...

# %%
min_tm = 2340
df.query('(DepTime==@min_tm) and (Origin=="ATL")')
# Out:
#          Unnamed: 0  FlightDate                 Airline Origin Dest  \
# 285978       285978  2022-04-15    Delta Air Lines Inc.    ATL  RSW
# 313537       313537  2022-04-10    Delta Air Lines Inc.    ATL  MEM
# 333062       333062  2022-04-26    Delta Air Lines Inc.    ATL  PBI
# 346388       346388  2022-04-20    Delta Air Lines Inc.    ATL  MKE
# 849375       269085  2022-02-26    Delta Air Lines Inc.    ATL  JAN
# 1291093      190851  2022-07-24    Delta Air Lines Inc.    ATL  BWI
# 1293085      192843  2022-07-30    Delta Air Lines Inc.    ATL  PHL
# 1294231      193989  2022-07-19    Delta Air Lines Inc.    ATL  ORD
# 1299094      198852  2022-07-24    Delta Air Lines Inc.    ATL  DFW
# 1305612      205370  2022-07-29    Delta Air Lines Inc.    ATL  MSY
# 1305746      205504  2022-07-03    Delta Air Lines Inc.    ATL  MCO
# 1306282      206040  2022-07-28    Delta Air Lines Inc.    ATL  TYS
# 1307802      207560  2022-07-03    Delta Air Lines Inc.    ATL  FLL
# ...

# %%
df[['Distance','ArrTime','ArrDelay']].mean()
# Out:
# Distance     797.865703
# ArrTime     1457.886018
# ArrDelay       7.528486
# dtype: float64

# %%
df[['Distance','ArrTime','ArrDelay']].agg(['mean','min','max'])
# Out:
#          Distance      ArrTime     ArrDelay
# mean   797.865703  1457.886018     7.528486
# min     31.000000     1.000000  -100.000000
# max   5095.000000  2400.000000  7232.000000

# %%
df[['Distance','ArrTime','ArrDelay']].agg(
    {'Distance':['mean','min','max'],
     'ArrTime':['min','max'],
     'ArrDelay':['min','max']}
)
# Out:
#          Distance  ArrTime  ArrDelay
# mean   797.865703      NaN       NaN
# min     31.000000      1.0    -100.0
# max   5095.000000   2400.0    7232.0

# %%
df['Airline'].unique()
# Out:
# array(['Commutair Aka Champlain Enterprises, Inc.',
#        'GoJet Airlines, LLC d/b/a United Express',
#        'Air Wisconsin Airlines Corp', 'Mesa Airlines Inc.',
#        'Southwest Airlines Co.', 'Republic Airlines', 'Endeavor Air Inc.',
#        'American Airlines Inc.', 'Capital Cargo International',
#        'SkyWest Airlines Inc.', 'Alaska Airlines Inc.', 'JetBlue Airways',
#        'Delta Air Lines Inc.', 'Frontier Airlines Inc.', 'Allegiant Air',
#        'Hawaiian Airlines Inc.', 'Envoy Air', 'Spirit Air Lines',
#        'Comair Inc.', 'Horizon Air', 'United Air Lines Inc.'],
#       dtype=object)

# %%
df['Airline'].nunique()
# Out:
# 21

# %%
df['Airline'].value_counts()
# Out:
# Airline
# Southwest Airlines Co.                       731925
# Delta Air Lines Inc.                         512114
# American Airlines Inc.                       495953
# SkyWest Airlines Inc.                        440807
# United Air Lines Inc.                        352009
# Republic Airlines                            197881
# JetBlue Airways                              156793
# Envoy Air                                    150758
# Endeavor Air Inc.                            142624
# Comair Inc.                                  135884
# Alaska Airlines Inc.                         129510
# Spirit Air Lines                             129208
# Frontier Airlines Inc.                        86557
# Allegiant Air                                 73504
# Mesa Airlines Inc.                            71972
# Horizon Air                                   56320
# Capital Cargo International                   52827
# Commutair Aka Champlain Enterprises, Inc.     44367
# ...

# %%
df[['Airline','Origin']].value_counts()
# Out:
# Airline                                    Origin
# Delta Air Lines Inc.                       ATL       120919
# American Airlines Inc.                     DFW        81239
#                                            CLT        57914
# United Air Lines Inc.                      DEN        46489
# Southwest Airlines Co.                     DEN        45398
#                                                       ...
# Frontier Airlines Inc.                     ICT            1
# Mesa Airlines Inc.                         MDT            1
# Air Wisconsin Airlines Corp                FWA            1
# Commutair Aka Champlain Enterprises, Inc.  DSM            1
# GoJet Airlines, LLC d/b/a United Express   MKE            1
# Name: count, Length: 2194, dtype: int64

# %%
df[['Airline','Origin']].value_counts().reset_index()
# Out:
#                                         Airline Origin   count
# 0                          Delta Air Lines Inc.    ATL  120919
# 1                        American Airlines Inc.    DFW   81239
# 2                        American Airlines Inc.    CLT   57914
# 3                         United Air Lines Inc.    DEN   46489
# 4                        Southwest Airlines Co.    DEN   45398
# ...                                         ...    ...     ...
# 2189                     Frontier Airlines Inc.    ICT       1
# 2190                         Mesa Airlines Inc.    MDT       1
# 2191                Air Wisconsin Airlines Corp    FWA       1
# 2192  Commutair Aka Champlain Enterprises, Inc.    DSM       1
# 2193   GoJet Airlines, LLC d/b/a United Express    MKE       1
#
# [2194 rows x 3 columns]

# %%
df[['CRSDepTime']].rank()
# Out:
#          CRSDepTime
# 0         1607887.5
# 1          595750.5
# 2         2549367.0
# 3         2344374.5
# 4         1615667.5
# ...             ...
# 4078313   3576231.5
# 4078314   3053676.0
# 4078315   2916510.0
# 4078316   3877928.5
# 4078317   1678988.0
#
# [4078318 rows x 1 columns]

# %%
df[['CRSDepTime']].shift(2, fill_value=0)
# Out:
#          CRSDepTime
# 0                 0
# 1                 0
# 2              1133
# 3               732
# 4              1529
# ...             ...
# 4078313        1829
# 4078314        2035
# 4078315        1949
# 4078316        1733
# 4078317        1700
#
# [4078318 rows x 1 columns]

# %%
df[['CRSDepTime']].cumsum()
# Out:
#          CRSDepTime
# 0              1133
# 1              1865
# 2              3394
# 3              4829
# 4              5964
# ...             ...
# 4078313  5422470512
# 4078314  5422472245
# 4078315  5422473945
# 4078316  5422476074
# 4078317  5422477228
#
# [4078318 rows x 1 columns]

# %%
df[['CRSDepTime']].cummax()
# Out:
#          CRSDepTime
# 0              1133
# 1              1133
# 2              1529
# 3              1529
# 4              1529
# ...             ...
# 4078313        2359
# 4078314        2359
# 4078315        2359
# 4078316        2359
# 4078317        2359
#
# [4078318 rows x 1 columns]

# %%
df[['CRSDepTime']].cummin()
# Out:
#          CRSDepTime
# 0              1133
# 1               732
# 2               732
# 3               732
# 4               732
# ...             ...
# 4078313           1
# 4078314           1
# 4078315           1
# 4078316           1
# 4078317           1
#
# [4078318 rows x 1 columns]

# %%
df[['DepDelayMinutes']].rolling(window=5)
# Out:
# Rolling [window=5,center=False,axis=0,method=single]

# %%
df[['DepDelayMinutes']].rolling(window=5).mean()
# Out:
#          DepDelayMinutes
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    0.0
# ...                  ...
# 4078313            144.2
# 4078314            108.4
# 4078315            145.0
# 4078316            142.8
# 4078317            112.0
#
# [4078318 rows x 1 columns]

# %%
df['DepTime'].clip(1000,2000)
# Out:
# 0          1123.0
# 1          1000.0
# 2          1514.0
# 3          1430.0
# 4          1135.0
#             ...
# 4078313    2000.0
# 4078314    1817.0
# 4078315    2000.0
# 4078316    2000.0
# 4078317    1148.0
# Name: DepTime, Length: 4078318, dtype: float64

# %%
df.groupby('Airline')[['DepDelay']].mean()
# Out:
#                                             DepDelay
# Airline
# Air Wisconsin Airlines Corp                 7.913244
# Alaska Airlines Inc.                        5.925950
# Allegiant Air                              19.061569
# American Airlines Inc.                     14.876556
# Capital Cargo International                 6.044430
# Comair Inc.                                12.693968
# Commutair Aka Champlain Enterprises, Inc.  12.093640
# Delta Air Lines Inc.                       11.398599
# Endeavor Air Inc.                           9.696390
# Envoy Air                                   6.883448
# Frontier Airlines Inc.                     20.052761
# GoJet Airlines, LLC d/b/a United Express   16.741980
# Hawaiian Airlines Inc.                      6.612163
# Horizon Air                                 5.892804
# JetBlue Airways                            26.009890
# Mesa Airlines Inc.                         15.714753
# Republic Airlines                          10.811487
# ...

# %%
df.groupby('Airline')[['DepDelay']].agg(['mean','min','max']).head(5)
# Out:
#                               DepDelay
#                                   mean   min     max
# Airline
# Air Wisconsin Airlines Corp   7.913244 -30.0  1355.0
# Alaska Airlines Inc.          5.925950 -63.0   915.0
# Allegiant Air                19.061569 -37.0  1917.0
# American Airlines Inc.       14.876556 -35.0  2994.0
# Capital Cargo International   6.044430 -34.0  1512.0

# %%
df_agg = df.groupby('Airline')[['DepDelay','ArrDelay']].agg(['mean','min','max']).head(5)
df_agg
# Out:
#                               DepDelay                 ArrDelay
#                                   mean   min     max       mean   min     max
# Airline
# Air Wisconsin Airlines Corp   7.913244 -30.0  1355.0   1.819183 -63.0  1353.0
# Alaska Airlines Inc.          5.925950 -63.0   915.0   3.170588 -76.0   908.0
# Allegiant Air                19.061569 -37.0  1917.0  20.519645 -69.0  1919.0
# American Airlines Inc.       14.876556 -35.0  2994.0   9.528696 -80.0  2977.0
# Capital Cargo International   6.044430 -34.0  1512.0   2.627024 -52.0  1490.0

# %%
df_agg.columns
# Out:
# MultiIndex([('DepDelay', 'mean'),
#             ('DepDelay',  'min'),
#             ('DepDelay',  'max'),
#             ('ArrDelay', 'mean'),
#             ('ArrDelay',  'min'),
#             ('ArrDelay',  'max')],
#            )

# %%
df_agg.columns.to_flat_index()
# Out:
# Index([('DepDelay', 'mean'),  ('DepDelay', 'min'),  ('DepDelay', 'max'),
#        ('ArrDelay', 'mean'),  ('ArrDelay', 'min'),  ('ArrDelay', 'max')],
#       dtype='object')

# %%
df_agg.columns = ['_'.join(x) for x in df_agg.columns]

# %%
df_agg
# Out:
#                              DepDelay_mean  DepDelay_min  DepDelay_max  \
# Airline
# Air Wisconsin Airlines Corp       7.913244         -30.0        1355.0
# Alaska Airlines Inc.              5.925950         -63.0         915.0
# Allegiant Air                    19.061569         -37.0        1917.0
# American Airlines Inc.           14.876556         -35.0        2994.0
# Capital Cargo International       6.044430         -34.0        1512.0
#
#                              ArrDelay_mean  ArrDelay_min  ArrDelay_max
# Airline
# Air Wisconsin Airlines Corp       1.819183         -63.0        1353.0
# Alaska Airlines Inc.              3.170588         -76.0         908.0
# Allegiant Air                    20.519645         -69.0        1919.0
# American Airlines Inc.            9.528696         -80.0        2977.0
# Capital Cargo International       2.627024         -52.0        1490.0

# %%
df.head(5)
# Out:
#    Unnamed: 0  FlightDate                                    Airline Origin  \
# 0           0  2022-04-04  Commutair Aka Champlain Enterprises, Inc.    GJT
# 1           1  2022-04-04  Commutair Aka Champlain Enterprises, Inc.    HRL
# 2           2  2022-04-04  Commutair Aka Champlain Enterprises, Inc.    DRO
# 3           3  2022-04-04  Commutair Aka Champlain Enterprises, Inc.    IAH
# 4           4  2022-04-04  Commutair Aka Champlain Enterprises, Inc.    DRO
#
#   Dest  Cancelled  Diverted  CRSDepTime  DepTime  DepDelayMinutes  DepDelay  \
# 0  DEN      False     False        1133   1123.0              0.0     -10.0
# 1  IAH      False     False         732    728.0              0.0      -4.0
# 2  DEN      False     False        1529   1514.0              0.0     -15.0
# 3  GPT      False     False        1435   1430.0              0.0      -5.0
# 4  DEN      False     False        1135   1135.0              0.0       0.0
#
# ...

# %%
df['DepTime2']=df['DepTime']/60

# %%
df.head()
# Out:
#    Unnamed: 0  FlightDate                                    Airline Origin  \
# 0           0  2022-04-04  Commutair Aka Champlain Enterprises, Inc.    GJT
# 1           1  2022-04-04  Commutair Aka Champlain Enterprises, Inc.    HRL
# 2           2  2022-04-04  Commutair Aka Champlain Enterprises, Inc.    DRO
# 3           3  2022-04-04  Commutair Aka Champlain Enterprises, Inc.    IAH
# 4           4  2022-04-04  Commutair Aka Champlain Enterprises, Inc.    DRO
#
#   Dest  Cancelled  Diverted  CRSDepTime  DepTime  DepDelayMinutes  DepDelay  \
# 0  DEN      False     False        1133   1123.0              0.0     -10.0
# 1  IAH      False     False         732    728.0              0.0      -4.0
# 2  DEN      False     False        1529   1514.0              0.0     -15.0
# 3  GPT      False     False        1435   1430.0              0.0      -5.0
# 4  DEN      False     False        1135   1135.0              0.0       0.0
#
# ...

# %%
df.assign(DepTime3 = df['DepTime']/15)
# Out:
#          Unnamed: 0  FlightDate                                    Airline  \
# 0                 0  2022-04-04  Commutair Aka Champlain Enterprises, Inc.
# 1                 1  2022-04-04  Commutair Aka Champlain Enterprises, Inc.
# 2                 2  2022-04-04  Commutair Aka Champlain Enterprises, Inc.
# 3                 3  2022-04-04  Commutair Aka Champlain Enterprises, Inc.
# 4                 4  2022-04-04  Commutair Aka Champlain Enterprises, Inc.
# ...             ...         ...                                        ...
# 4078313      590537  2022-03-31                          Republic Airlines
# 4078314      590538  2022-03-17                          Republic Airlines
# 4078315      590539  2022-03-08                          Republic Airlines
# 4078316      590540  2022-03-25                          Republic Airlines
# 4078317      590541  2022-03-07                          Republic Airlines
#
#         Origin Dest  Cancelled  Diverted  CRSDepTime  DepTime  \
# ...

# %%
df.sort_values('ArrDelay')
# Out:
#          Unnamed: 0  FlightDate               Airline Origin Dest  Cancelled  \
# 3336665      412626  2022-01-20       JetBlue Airways    STT  EWR      False
# 3756032      268256  2022-03-30       JetBlue Airways    STT  JFK      False
# 3322408      398369  2022-01-22       JetBlue Airways    STT  JFK      False
# 284876       284876  2022-04-12  Delta Air Lines Inc.    SAN  ATL      False
# 2302544      583512  2022-05-12     Republic Airlines    LGA  IAH      False
# ...             ...         ...                   ...    ...  ...        ...
# 4078311      590535  2022-03-31     Republic Airlines    EWR  PIT       True
# 4078313      590537  2022-03-31     Republic Airlines    MSY  EWR      False
# 4078314      590538  2022-03-17     Republic Airlines    CLT  EWR       True
# 4078316      590540  2022-03-25     Republic Airlines    EWR  PIT      False
# 4078317      590541  2022-03-07     Republic Airlines    EWR  RDU      False
#
# ...

# %%
df[['FlightDate','Airline','ArrDelay']].sort_values('ArrDelay', ascending=False)\
    .reset_index(drop=True)
# Out:
#          FlightDate                 Airline  ArrDelay
# 0        2022-05-23       Republic Airlines    7232.0
# 1        2022-06-18               Envoy Air    5324.0
# 2        2022-05-16       Republic Airlines    4318.0
# 3        2022-06-05  American Airlines Inc.    2977.0
# 4        2022-03-26  American Airlines Inc.    2934.0
# ...             ...                     ...       ...
# 4078313  2022-03-31       Republic Airlines       NaN
# 4078314  2022-03-31       Republic Airlines       NaN
# 4078315  2022-03-17       Republic Airlines       NaN
# 4078316  2022-03-25       Republic Airlines       NaN
# 4078317  2022-03-07       Republic Airlines       NaN
#
# [4078318 rows x 3 columns]

# %%
df[['FlightDate','Airline','ArrDelay']].isna()
# Out:
#          FlightDate  Airline  ArrDelay
# 0             False    False     False
# 1             False    False     False
# 2             False    False     False
# 3             False    False     False
# 4             False    False     False
# ...             ...      ...       ...
# 4078313       False    False      True
# 4078314       False    False      True
# 4078315       False    False     False
# 4078316       False    False      True
# 4078317       False    False      True
#
# [4078318 rows x 3 columns]

# %%
df[['FlightDate','Airline','ArrDelay']].isna().sum()
# Out:
# FlightDate         0
# Airline            0
# ArrDelay      133402
# dtype: int64

# %%
df[['FlightDate','Airline','ArrDelay']].dropna()
# Out:
#          FlightDate                                    Airline  ArrDelay
# 0        2022-04-04  Commutair Aka Champlain Enterprises, Inc.     -17.0
# 1        2022-04-04  Commutair Aka Champlain Enterprises, Inc.      -1.0
# 2        2022-04-04  Commutair Aka Champlain Enterprises, Inc.      -3.0
# 3        2022-04-04  Commutair Aka Champlain Enterprises, Inc.     -18.0
# 4        2022-04-04  Commutair Aka Champlain Enterprises, Inc.       6.0
# ...             ...                                        ...       ...
# 4078308  2022-03-31                          Republic Airlines     207.0
# 4078309  2022-03-31                          Republic Airlines     201.0
# 4078310  2022-03-31                          Republic Airlines     180.0
# 4078312  2022-03-19                          Republic Airlines     135.0
# 4078315  2022-03-08                          Republic Airlines     381.0
#
# [3944916 rows x 3 columns]

# %%
df[['FlightDate','Airline','ArrDelay']].dropna(subset=['Airline'])
# Out:
#          FlightDate                                    Airline  ArrDelay
# 0        2022-04-04  Commutair Aka Champlain Enterprises, Inc.     -17.0
# 1        2022-04-04  Commutair Aka Champlain Enterprises, Inc.      -1.0
# 2        2022-04-04  Commutair Aka Champlain Enterprises, Inc.      -3.0
# 3        2022-04-04  Commutair Aka Champlain Enterprises, Inc.     -18.0
# 4        2022-04-04  Commutair Aka Champlain Enterprises, Inc.       6.0
# ...             ...                                        ...       ...
# 4078313  2022-03-31                          Republic Airlines       NaN
# 4078314  2022-03-17                          Republic Airlines       NaN
# 4078315  2022-03-08                          Republic Airlines     381.0
# 4078316  2022-03-25                          Republic Airlines       NaN
# 4078317  2022-03-07                          Republic Airlines       NaN
#
# [4078318 rows x 3 columns]

# %%
df[['FlightDate','Airline','ArrDelay']].fillna(-44)
# Out:
#          FlightDate                                    Airline  ArrDelay
# 0        2022-04-04  Commutair Aka Champlain Enterprises, Inc.     -17.0
# 1        2022-04-04  Commutair Aka Champlain Enterprises, Inc.      -1.0
# 2        2022-04-04  Commutair Aka Champlain Enterprises, Inc.      -3.0
# 3        2022-04-04  Commutair Aka Champlain Enterprises, Inc.     -18.0
# 4        2022-04-04  Commutair Aka Champlain Enterprises, Inc.       6.0
# ...             ...                                        ...       ...
# 4078313  2022-03-31                          Republic Airlines     -44.0
# 4078314  2022-03-17                          Republic Airlines     -44.0
# 4078315  2022-03-08                          Republic Airlines     381.0
# 4078316  2022-03-25                          Republic Airlines     -44.0
# 4078317  2022-03-07                          Republic Airlines     -44.0
#
# [4078318 rows x 3 columns]

# %%
df['ArrDelay'].fillna(df['ArrDelay'].mean())
# Out:
# 0          -17.000000
# 1           -1.000000
# 2           -3.000000
# 3          -18.000000
# 4            6.000000
#               ...
# 4078313      7.528486
# 4078314      7.528486
# 4078315    381.000000
# 4078316      7.528486
# 4078317      7.528486
# Name: ArrDelay, Length: 4078318, dtype: float64

# %%
df1 = df.query('Airline == "Republic Airlines"').copy()
df2 = df.query('Airline == "Commutair Aka Champlain Enterprises, Inc."').copy()

# %%
df_stack = pd.concat([df1,df2])
df_stack.head(3)
# Out:
#         Unnamed: 0  FlightDate            Airline Origin Dest  Cancelled  \
# 115119      115119  2022-04-02  Republic Airlines    ALB  MIA      False
# 115120      115120  2022-04-01  Republic Airlines    DCA  PWM      False
# 115121      115121  2022-04-03  Republic Airlines    DCA  PWM      False
#
#         Diverted  CRSDepTime  DepTime  DepDelayMinutes  DepDelay  ArrTime  \
# 115119     False         729    724.0              0.0      -5.0   1048.0
# 115120     False        1900   1852.0              0.0      -8.0   2026.0
# 115121     False        1900   1851.0              0.0      -9.0   2036.0
#
#         ArrDelayMinutes  AirTime  CRSElapsedTime  ActualElapsedTime  Distance  \
# 115119              0.0    182.0           206.0              204.0    1225.0
# 115120              0.0     78.0            99.0               94.0     482.0
# 115121              0.0     78.0            99.0              105.0     482.0
#
# ...

# %%
df1 = df1.reset_index(drop=True)
df2 = df2.reset_index(drop=True)

df_side = pd.concat([df1,df2], axis=1)
df_side.head(2)
# Out:
#    Unnamed: 0  FlightDate            Airline Origin Dest  Cancelled  Diverted  \
# 0      115119  2022-04-02  Republic Airlines    ALB  MIA      False     False
# 1      115120  2022-04-01  Republic Airlines    DCA  PWM      False     False
#
#    CRSDepTime  DepTime  DepDelayMinutes  DepDelay  ArrTime ArrDelayMinutes  \
# 0         729    724.0              0.0      -5.0   1048.0             0.0
# 1        1900   1852.0              0.0      -8.0   2026.0             0.0
#
#    AirTime  CRSElapsedTime  ActualElapsedTime  Distance  Year  Quarter  Month  \
# 0    182.0           206.0              204.0    1225.0  2022        2      4
# 1     78.0            99.0               94.0     482.0  2022        2      4
#
#    DayofMonth DayOfWeek  Marketing_Airline_Network  \
# 0           2         6                         AA
# 1           1         5                         AA
#
#    Operated_or_Branded_Code_Share_Partners  DOT_ID_Marketing_Airline  \
# ...

# %%
df1.shape, df2.shape, df_stack.shape, df_side.shape
# Out:
# ((197881, 62), (44367, 62), (242248, 62), (197881, 124))

# %%
df_side['Origin']
# Out:
#        Origin Origin
# 0         ALB    GJT
# 1         DCA    HRL
# 2         DCA    DRO
# 3         DCA    IAH
# 4         JFK    DRO
# ...       ...    ...
# 197876    MSY    NaN
# 197877    CLT    NaN
# 197878    ALB    NaN
# 197879    EWR    NaN
# 197880    EWR    NaN
#
# [197881 rows x 2 columns]

# %%
df1 = df.groupby(['Airline', 'FlightDate'])[['DepDelay']].mean().reset_index()
df2 = df.groupby(['Airline', 'FlightDate'])[['ArrDelay']].mean().reset_index()

# %%
df2
# Out:
#                           Airline  FlightDate   ArrDelay
# 0     Air Wisconsin Airlines Corp  2022-01-01   5.717949
# 1     Air Wisconsin Airlines Corp  2022-01-02  36.641176
# 2     Air Wisconsin Airlines Corp  2022-01-03  36.525316
# 3     Air Wisconsin Airlines Corp  2022-01-04  -5.842391
# 4     Air Wisconsin Airlines Corp  2022-01-05  20.250000
# ...                           ...         ...        ...
# 4447        United Air Lines Inc.  2022-07-27   4.912778
# 4448        United Air Lines Inc.  2022-07-28   6.640288
# 4449        United Air Lines Inc.  2022-07-29   4.629425
# 4450        United Air Lines Inc.  2022-07-30  -4.716889
# 4451        United Air Lines Inc.  2022-07-31   4.626857
#
# [4452 rows x 3 columns]

# %%
df1.merge(df2)
# Out:
#                           Airline  FlightDate   DepDelay   ArrDelay
# 0     Air Wisconsin Airlines Corp  2022-01-01   8.784810   5.717949
# 1     Air Wisconsin Airlines Corp  2022-01-02  41.766082  36.641176
# 2     Air Wisconsin Airlines Corp  2022-01-03  46.183544  36.525316
# 3     Air Wisconsin Airlines Corp  2022-01-04   6.141304  -5.842391
# 4     Air Wisconsin Airlines Corp  2022-01-05  20.532967  20.250000
# ...                           ...         ...        ...        ...
# 4447        United Air Lines Inc.  2022-07-27  12.064677   4.912778
# 4448        United Air Lines Inc.  2022-07-28  14.437948   6.640288
# 4449        United Air Lines Inc.  2022-07-29  11.029185   4.629425
# 4450        United Air Lines Inc.  2022-07-30   6.192961  -4.716889
# 4451        United Air Lines Inc.  2022-07-31  12.688534   4.626857
#
# [4452 rows x 4 columns]

# %%
df1.merge(df2, how='outer')
# Out:
#                           Airline  FlightDate   DepDelay   ArrDelay
# 0     Air Wisconsin Airlines Corp  2022-01-01   8.784810   5.717949
# 1     Air Wisconsin Airlines Corp  2022-01-02  41.766082  36.641176
# 2     Air Wisconsin Airlines Corp  2022-01-03  46.183544  36.525316
# 3     Air Wisconsin Airlines Corp  2022-01-04   6.141304  -5.842391
# 4     Air Wisconsin Airlines Corp  2022-01-05  20.532967  20.250000
# ...                           ...         ...        ...        ...
# 4447        United Air Lines Inc.  2022-07-27  12.064677   4.912778
# 4448        United Air Lines Inc.  2022-07-28  14.437948   6.640288
# 4449        United Air Lines Inc.  2022-07-29  11.029185   4.629425
# 4450        United Air Lines Inc.  2022-07-30   6.192961  -4.716889
# 4451        United Air Lines Inc.  2022-07-31  12.688534   4.626857
#
# [4452 rows x 4 columns]

# %%
df1.merge(df2, how='right')
# Out:
#                           Airline  FlightDate   DepDelay   ArrDelay
# 0     Air Wisconsin Airlines Corp  2022-01-01   8.784810   5.717949
# 1     Air Wisconsin Airlines Corp  2022-01-02  41.766082  36.641176
# 2     Air Wisconsin Airlines Corp  2022-01-03  46.183544  36.525316
# 3     Air Wisconsin Airlines Corp  2022-01-04   6.141304  -5.842391
# 4     Air Wisconsin Airlines Corp  2022-01-05  20.532967  20.250000
# ...                           ...         ...        ...        ...
# 4447        United Air Lines Inc.  2022-07-27  12.064677   4.912778
# 4448        United Air Lines Inc.  2022-07-28  14.437948   6.640288
# 4449        United Air Lines Inc.  2022-07-29  11.029185   4.629425
# 4450        United Air Lines Inc.  2022-07-30   6.192961  -4.716889
# 4451        United Air Lines Inc.  2022-07-31  12.688534   4.626857
#
# [4452 rows x 4 columns]

# %%
pd.merge(df1,df2, on=['Airline'])
# Out:
#                             Airline FlightDate_x   DepDelay FlightDate_y  \
# 0       Air Wisconsin Airlines Corp   2022-01-01   8.784810   2022-01-01
# 1       Air Wisconsin Airlines Corp   2022-01-01   8.784810   2022-01-02
# 2       Air Wisconsin Airlines Corp   2022-01-01   8.784810   2022-01-03
# 3       Air Wisconsin Airlines Corp   2022-01-01   8.784810   2022-01-04
# 4       Air Wisconsin Airlines Corp   2022-01-01   8.784810   2022-01-05
# ...                             ...          ...        ...          ...
# 943819        United Air Lines Inc.   2022-07-31  12.688534   2022-07-27
# 943820        United Air Lines Inc.   2022-07-31  12.688534   2022-07-28
# 943821        United Air Lines Inc.   2022-07-31  12.688534   2022-07-29
# 943822        United Air Lines Inc.   2022-07-31  12.688534   2022-07-30
# 943823        United Air Lines Inc.   2022-07-31  12.688534   2022-07-31
#
#          ArrDelay
# 0        5.717949
# 1       36.641176
# 2       36.525316
# ...

# %%
pd.merge(df1,df2, on=['Airline'],suffixes=('_dep','_arr'))
# Out:
#                             Airline FlightDate_dep   DepDelay FlightDate_arr  \
# 0       Air Wisconsin Airlines Corp     2022-01-01   8.784810     2022-01-01
# 1       Air Wisconsin Airlines Corp     2022-01-01   8.784810     2022-01-02
# 2       Air Wisconsin Airlines Corp     2022-01-01   8.784810     2022-01-03
# 3       Air Wisconsin Airlines Corp     2022-01-01   8.784810     2022-01-04
# 4       Air Wisconsin Airlines Corp     2022-01-01   8.784810     2022-01-05
# ...                             ...            ...        ...            ...
# 943819        United Air Lines Inc.     2022-07-31  12.688534     2022-07-27
# 943820        United Air Lines Inc.     2022-07-31  12.688534     2022-07-28
# 943821        United Air Lines Inc.     2022-07-31  12.688534     2022-07-29
# 943822        United Air Lines Inc.     2022-07-31  12.688534     2022-07-30
# 943823        United Air Lines Inc.     2022-07-31  12.688534     2022-07-31
#
#          ArrDelay
# 0        5.717949
# ...

# %%
pd.merge(df1,df2, on=['Airline','FlightDate'])
# Out:
#                           Airline  FlightDate   DepDelay   ArrDelay
# 0     Air Wisconsin Airlines Corp  2022-01-01   8.784810   5.717949
# 1     Air Wisconsin Airlines Corp  2022-01-02  41.766082  36.641176
# 2     Air Wisconsin Airlines Corp  2022-01-03  46.183544  36.525316
# 3     Air Wisconsin Airlines Corp  2022-01-04   6.141304  -5.842391
# 4     Air Wisconsin Airlines Corp  2022-01-05  20.532967  20.250000
# ...                           ...         ...        ...        ...
# 4447        United Air Lines Inc.  2022-07-27  12.064677   4.912778
# 4448        United Air Lines Inc.  2022-07-28  14.437948   6.640288
# 4449        United Air Lines Inc.  2022-07-29  11.029185   4.629425
# 4450        United Air Lines Inc.  2022-07-30   6.192961  -4.716889
# 4451        United Air Lines Inc.  2022-07-31  12.688534   4.626857
#
# [4452 rows x 4 columns]

# %%
pd.merge(df1, df2, left_on=['Airline'], right_on=['Airline'])
# Out:
#                             Airline FlightDate_x   DepDelay FlightDate_y  \
# 0       Air Wisconsin Airlines Corp   2022-01-01   8.784810   2022-01-01
# 1       Air Wisconsin Airlines Corp   2022-01-01   8.784810   2022-01-02
# 2       Air Wisconsin Airlines Corp   2022-01-01   8.784810   2022-01-03
# 3       Air Wisconsin Airlines Corp   2022-01-01   8.784810   2022-01-04
# 4       Air Wisconsin Airlines Corp   2022-01-01   8.784810   2022-01-05
# ...                             ...          ...        ...          ...
# 943819        United Air Lines Inc.   2022-07-31  12.688534   2022-07-27
# 943820        United Air Lines Inc.   2022-07-31  12.688534   2022-07-28
# 943821        United Air Lines Inc.   2022-07-31  12.688534   2022-07-29
# 943822        United Air Lines Inc.   2022-07-31  12.688534   2022-07-30
# 943823        United Air Lines Inc.   2022-07-31  12.688534   2022-07-31
#
#          ArrDelay
# 0        5.717949
# 1       36.641176
# 2       36.525316
# ...
